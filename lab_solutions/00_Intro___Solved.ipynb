# %% [markdown]
# # 0. [OPTIONAL] Installing course dependencies
#
# These are dependencies for the whole course.

# %%
# !pip install -r ../requirements.txt

# %% [markdown]
# You may skip the next block for now. You will need `ffmpeg` on week 12.

# %%
# !conda update -y base conda
# !conda install -c conda-forge ffmpeg -y

# %% [markdown]
# Run the next cell if you want to download embedding model, but this is not required during this lab. You can do it later.

# %%
# !python -m spacy download en_trf_distilbertbaseuncased_lg

# %% [markdown]
# # 1. Touching the Internet
#
# Solve the following task.
# 1. Download [this page](https://raw.githubusercontent.com/IUCVLab/information-retrieval/main/datasets/facts.txt)
# 2. Save it to the file with the **unique** name derived from the URL. NB File with another URL should not be save into the file with this name. E.g. [this file](https://github.com/IUCVLab/information-retrieval/blob/main/datasets/facts.txt) is another file with another content!
#
# Hints:
# - [requests](https://docs.python-requests.org/en/latest/) library is cool.
# - [hashlib](https://docs.python.org/3/library/hashlib.html) may help with computing hash strings.
# - when you download and save the data, don't try to encode and decode it. Use binary format when working with streams and files. <span style="color:red">Discuss with your TA which encodings you know and how they differ</span>.

# %%
import requests
import hashlib

url1 = "https://raw.githubusercontent.com/IUCVLab/information-retrieval/main/datasets/facts.txt"
url2 = "https://github.com/IUCVLab/information-retrieval/blob/main/datasets/facts.txt"

# TODO: download and save these documents
urls = [url1, url2]
scraped_content = {}

for url in urls:
  content = requests.get(url)

  h = hashlib.new('sha256')
  h.update(url.encode())
  out_file = h.hexdigest()
  # scraped_content[out_file] = content.text
  with open(out_file, 'w') as f: f.write(content.text)

# %% [markdown]
# # 2. Parsing different formats
#
# Most probably, if you meet something in the Internet, this is one of: binary, plain text, XML, or json. XML then splits into xHTML, RSS, Atom, SOAP, XML-RPC, ... . Your task is to learn, how to process different formats.
#
# ## 2.1. JSON
#
# In [the given file](http://sprotasov.ru/data/postnauka.txt) there is valid json. Parse this file and print all video URLs, which have `computer science` tag. Use built-in features of `requests`, or just a `json` library ([ref](https://docs.python.org/3/library/json.html)).
#
# Hint:
# - if the file has issues with parsing read about [the difference](https://stackoverflow.com/questions/57152985/what-is-the-difference-between-utf-8-and-utf-8-sig).

# %%
import json
import requests

url = "http://sprotasov.ru/data/postnauka.txt"


raw = requests.get(url)
loaded_json = json.loads(raw.text.lstrip('\ufeff'))
# loaded_json
[x['url'] for x in filter( lambda x: 'computer science' in x['tags'], loaded_json)]
# Out:
# ['http://postnauka.ru/talks/31897',
#  'http://postnauka.ru/video/24306',
#  'http://postnauka.ru/faq/46974']

# %% [markdown]
# ## 2.2. HTML
#
# For a given StackExchange answer extract logins of the contributors (who asked and who answered) with votes. [bs4](https://beautiful-soup-4.readthedocs.io/en/latest/) will help you to do the job.
#
# I can recommend to use CSS or XPath selectors. `div` elements with `post-layout` class represent answers. Inside there are `div` with `votecell` class stroring votes number and `div` with class `user-details` storing user info. My personal recommendation is to use `css selectors`, which are [documented here](https://beautiful-soup-4.readthedocs.io/en/latest/#css-selectors).

# %%
import requests
from bs4 import BeautifulSoup

url = "https://math.stackexchange.com/questions/411486/"\
        "understanding-the-singular-value-decomposition-svd"
print(url)

# TODO. Your code here should parse HTML source page and find contributors of the repository.

result = requests.get(url).text
doc = BeautifulSoup(result, "html.parser")


users = doc.find_all('div', {'class': 'user-details'})
for user in users:
  name = user.find('a')
  if name:
    print(name.text)

votes = doc.find_all('div', {'class': 'js-vote-count'})
for vote in votes:
    print(vote.text)
# Out:
# https://math.stackexchange.com/questions/411486/understanding-the-singular-value-decomposition-svd
# Rodrigo de Azevedo
# Celdor
# Ittay Weiss
# Tomasz Bartkowiak
# Bart Vanderbeke
# Bart Vanderbeke
# hgfei
# littleO
# TheSHETTY-Paradise
#
#             23
#
#
#             17
#
#
#             10
#
#
#             4
#
#
#             3
#
#
#             2
#
#
#             1
#
#
#             1

# %% [markdown]
# # 2.3. RSS feed
#
# A lot of information is already organized in typed XML documents. Podcasts, for example, are just RSS feed. Parse [the feed of this podcast](http://sprotasov.ru/podcast/rss.xml) and print out:
# - the number of episodes
# - the length of the time span between the first and the last episodes (in days).
#
# Use [`feedparser` library for this](https://waylonwalker.com/parsing-rss-python/).

# %%
# !pip install feedparser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting feedparser
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 KB 3.7 MB/s eta 0:00:00
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=ac0a2929b66d4dcbc8426dc62eea20b48c8c55a923f256dc8a3bcb6787a77e0c
#   Stored in directory: /root/.cache/pip/wheels/83/63/2f/117884c3b19d46b64d3d61690333aa80c88dc14050e269c546
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.10 sgmllib3k-1.0.0

# %%
import feedparser
rss = 'http://sprotasov.ru/podcast/rss.xml'
feedparser.parse(rss) 

# TODO: complete the code to compute the time span of all the episodes.
# Out:
# {'bozo': False,
#  'entries': [{'title': '17 - квантовые компьютеры против Дьяконова',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '17 - квантовые компьютеры против Дьяконова'},
#    'summary': 'В 2020 году вышла книга Михаил Игоревича Дьяконова "Will We Ever Have a Quantum Computer?". \nВ этой книге автор ставит под сомнение возможность создания универсального квантового компьютера, \nа также критикует саму область квантовых вычислений.\nЯ выступаю адвокатом обороняющейся стороны и робко отбиваюсь от аргументов известного ученого.\nКнига небольшая, её можно прочитать тут - https://link.springer.com/book/10.1007/978-3-030-42019-2',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'В 2020 году вышла книга Михаил Игоревича Дьяконова "Will We Ever Have a Quantum Computer?". \nВ этой книге автор ставит под сомнение возможность создания универсального квантового компьютера, \nа также критикует саму область квантовых вычислений.\nЯ выступаю адвокатом обороняющейся стороны и робко отбиваюсь от аргументов известного ученого.\nКнига небольшая, её можно прочитать тут - https://link.springer.com/book/10.1007/978-3-030-42019-2'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'В 2020 году вышла книга Михаил Игоревича Дьяконова "Will We Ever Have a Quantum Computer?". \nВ этой книге автор ставит под сомнение возможность создания универсального квантового компьютера, \nа также критикует саму область квантовых вычислений.\nЯ выступаю адвокатом обороняющейся стороны и робко отбиваюсь от аргументов известного ученого.\nКнига небольшая, её можно прочитать тут - https://link.springer.com/book/10.1007/978-3-030-42019-2'}],
#    'links': [{'length': '110702001',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-17.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Mon, 14 November 2022 21:25:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2022, tm_mon=11, tm_mday=14, tm_hour=18, tm_min=25, tm_sec=0, tm_wday=0, tm_yday=318, tm_isdst=0),
#    'itunes_duration': '00:46:08',
#    'id': 'Origin of species 17',
#    'guidislink': False},
#   {'title': '16 - Errata с Араратом',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '16 - Errata с Араратом'},
#    'summary': 'В этом очень расслабленном выпуске я разбираю ошибки прошлого и рассказываю про то, какой проект мы сейчас делаем с казанскими физиками. В выпуске я упоминаю сериал Devs: https://www.imdb.com/title/tt8134186/ .',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'В этом очень расслабленном выпуске я разбираю ошибки прошлого и рассказываю про то, какой проект мы сейчас делаем с казанскими физиками. В выпуске я упоминаю сериал Devs: https://www.imdb.com/title/tt8134186/ .'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'В этом очень расслабленном выпуске я разбираю ошибки прошлого и рассказываю про то, какой проект мы сейчас делаем с казанскими физиками. В выпуске я упоминаю сериал Devs: https://www.imdb.com/title/tt8134186/ .'}],
#    'links': [{'length': '103591430',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-16.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Wed, 30 March 2022 22:30:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2022, tm_mon=3, tm_mday=30, tm_hour=19, tm_min=30, tm_sec=0, tm_wday=2, tm_yday=89, tm_isdst=0),
#    'itunes_duration': '00:43:10',
#    'id': 'Origin of species 16',
#    'guidislink': False},
#   {'title': '15 - собираем квантовый компьютер на кухне',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '15 - собираем квантовый компьютер на кухне'},
#    'summary': 'Ключевую роль в классическом компьютере играет процессор. Он берёт значения из регистров и преобразует их, используя систему разрешённых команд. \nВ этом подкасте обсуждаем, что является аналогом регистров и команд в квантовом компьютере, и из каких элементов это всё можно собрать.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Ключевую роль в классическом компьютере играет процессор. Он берёт значения из регистров и преобразует их, используя систему разрешённых команд. \nВ этом подкасте обсуждаем, что является аналогом регистров и команд в квантовом компьютере, и из каких элементов это всё можно собрать.'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'Ключевую роль в классическом компьютере играет процессор. Он берёт значения из регистров и преобразует их, используя систему разрешённых команд. \nВ этом подкасте обсуждаем, что является аналогом регистров и команд в квантовом компьютере, и из каких элементов это всё можно собрать.'}],
#    'links': [{'length': '70540293',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-15.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Wed, 21 July 2021 15:36:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=7, tm_mday=21, tm_hour=12, tm_min=36, tm_sec=0, tm_wday=2, tm_yday=202, tm_isdst=0),
#    'itunes_duration': '00:48:59',
#    'id': 'Origin of species 15',
#    'guidislink': False},
#   {'title': '14 - краш курс квантовой физики',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '14 - краш курс квантовой физики'},
#    'summary': 'Второй сезон подкаста будет про то, как работают квантовые компьютеры. Чтобы понимать основные вещи про них, нужно познакомиться с понятиями вектора состояния, суперпозиции и запутанности. Что ж, попробуем. \n\nВ подкасте звучит музыка Seva Nature (https://sevanature.fanlink.to/mayak-luch).',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Второй сезон подкаста будет про то, как работают квантовые компьютеры. Чтобы понимать основные вещи про них, нужно познакомиться с понятиями вектора состояния, суперпозиции и запутанности. Что ж, попробуем. \n\nВ подкасте звучит музыка Seva Nature (https://sevanature.fanlink.to/mayak-luch).'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'Второй сезон подкаста будет про то, как работают квантовые компьютеры. Чтобы понимать основные вещи про них, нужно познакомиться с понятиями вектора состояния, суперпозиции и запутанности. Что ж, попробуем. \n\nВ подкасте звучит музыка Seva Nature (https://sevanature.fanlink.to/mayak-luch).'}],
#    'links': [{'length': '36301457',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-14.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Thu, 29 June 2021 02:50:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=6, tm_mday=28, tm_hour=23, tm_min=50, tm_sec=0, tm_wday=0, tm_yday=179, tm_isdst=0),
#    'itunes_duration': '00:41:48',
#    'id': 'Origin of species 14',
#    'guidislink': False},
#   {'title': '13 - архитектуры компьютера',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '13 - архитектуры компьютера'},
#    'summary': 'В сороковые годы XX века люди подошли к созданию компьютеров общего назначения. Решения, принятые тогда, до сих пор во многом влияют на то, как функционируют современные компьютеры.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'В сороковые годы XX века люди подошли к созданию компьютеров общего назначения. Решения, принятые тогда, до сих пор во многом влияют на то, как функционируют современные компьютеры.'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'В сороковые годы XX века люди подошли к созданию компьютеров общего назначения. Решения, принятые тогда, до сих пор во многом влияют на то, как функционируют современные компьютеры.'}],
#    'links': [{'length': '20585148',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-13.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Thu, 5 May 2018 15:25:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2018, tm_mon=5, tm_mday=5, tm_hour=12, tm_min=25, tm_sec=0, tm_wday=5, tm_yday=125, tm_isdst=0),
#    'itunes_duration': '00:14:17',
#    'id': 'Origin of species 13',
#    'guidislink': False},
#   {'title': '12 - понимание языка',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '12 - понимание языка'},
#    'summary': 'Как так вышло, что машины понимают голос людей, и сами могут говорить на наших языках? Поговорим об этом, и о том, где в нашей речи потерялся смысл.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Как так вышло, что машины понимают голос людей, и сами могут говорить на наших языках? Поговорим об этом, и о том, где в нашей речи потерялся смысл.'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'Как так вышло, что машины понимают голос людей, и сами могут говорить на наших языках? Поговорим об этом, и о том, где в нашей речи потерялся смысл.'}],
#    'links': [{'length': '12470039',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-12.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Tue, 13 Feb 2018 09:45:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2018, tm_mon=2, tm_mday=13, tm_hour=6, tm_min=45, tm_sec=0, tm_wday=1, tm_yday=44, tm_isdst=0),
#    'itunes_duration': '00:08:39',
#    'id': 'Origin of species 12',
#    'guidislink': False},
#   {'title': '11 - новогодняя страшилка',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '11 - новогодняя страшилка'},
#    'summary': 'В этом выпуске роботы обсудят, какие методы им применять, чтобы обмануть человека. Этим непознавательным выпуском желаю всем страшненького будущего и новом году!',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'В этом выпуске роботы обсудят, какие методы им применять, чтобы обмануть человека. Этим непознавательным выпуском желаю всем страшненького будущего и новом году!'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'В этом выпуске роботы обсудят, какие методы им применять, чтобы обмануть человека. Этим непознавательным выпуском желаю всем страшненького будущего и новом году!'}],
#    'links': [{'length': '7381814',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-11.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Sun, 31 Dec 2017 01:00:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2017, tm_mon=12, tm_mday=30, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=5, tm_yday=364, tm_isdst=0),
#    'itunes_duration': '00:07:41',
#    'id': 'Origin of species 11',
#    'guidislink': False},
#   {'title': '10 - Виды параллельных вычислений',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '10 - Виды параллельных вычислений'},
#    'summary': 'За полвека придумано много технологий распараллеливания вычислений. В коротком выпуске много терминов и технологий: от CDC 8600 до Intel Xeon, от векторизации до CUDA, и ещё немножко. И не забывайте про закон Амдала!',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'За полвека придумано много технологий распараллеливания вычислений. В коротком выпуске много терминов и технологий: от CDC 8600 до Intel Xeon, от векторизации до CUDA, и ещё немножко. И не забывайте про закон Амдала!'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'За полвека придумано много технологий распараллеливания вычислений. В коротком выпуске много терминов и технологий: от CDC 8600 до Intel Xeon, от векторизации до CUDA, и ещё немножко. И не забывайте про закон Амдала!'}],
#    'links': [{'length': '9797634',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-10.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Sun, 06 Dec 2017 01:00:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2017, tm_mon=12, tm_mday=5, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=339, tm_isdst=0),
#    'itunes_duration': '00:10:12',
#    'id': 'Origin of species 10',
#    'guidislink': False},
#   {'title': '09 - Принцип работы квантового компьютера',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '09 - Принцип работы квантового компьютера'},
#    'summary': 'Квантовый компьютер не решит всех проблем, и ещё даже толком не создан. Но как он работает лучше всё-таки знать!',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Квантовый компьютер не решит всех проблем, и ещё даже толком не создан. Но как он работает лучше всё-таки знать!'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'Квантовый компьютер не решит всех проблем, и ещё даже толком не создан. Но как он работает лучше всё-таки знать!'}],
#    'links': [{'length': '9220029',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-09.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Sun, 12 Nov 2017 19:00:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2017, tm_mon=11, tm_mday=12, tm_hour=16, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=316, tm_isdst=0),
#    'itunes_duration': '00:09:36',
#    'id': 'Origin of species 09',
#    'guidislink': False},
#   {'title': '08 - Химия компьютера',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '08 - Химия компьютера'},
#    'summary': 'Если вы до сих пор думаете, что компьютер состоит из железок, то значит мы не зря делали этот выпуск! Рассказываем, из чего делали, делают и будут делать компьютеры и комплектующие.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Если вы до сих пор думаете, что компьютер состоит из железок, то значит мы не зря делали этот выпуск! Рассказываем, из чего делали, делают и будут делать компьютеры и комплектующие.'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'Если вы до сих пор думаете, что компьютер состоит из железок, то значит мы не зря делали этот выпуск! Рассказываем, из чего делали, делают и будут делать компьютеры и комплектующие.'}],
#    'links': [{'length': '22043420',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-08.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Mon, 09 Oct 2017 22:00:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2017, tm_mon=10, tm_mday=9, tm_hour=19, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=282, tm_isdst=0),
#    'itunes_duration': '00:16:07',
#    'id': 'Origin of species 08',
#    'guidislink': False},
#   {'title': '07 - Искусственные нейронные сети',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '07 - Искусственные нейронные сети'},
#    'summary': 'Одни из самых известных, и одновременно популярных, моделей машиннинного обучения - искусственные нейронные сети. Откуда они взялись и куда идут - в этом выпуске подкаста.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Одни из самых известных, и одновременно популярных, моделей машиннинного обучения - искусственные нейронные сети. Откуда они взялись и куда идут - в этом выпуске подкаста.'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'Одни из самых известных, и одновременно популярных, моделей машиннинного обучения - искусственные нейронные сети. Откуда они взялись и куда идут - в этом выпуске подкаста.'}],
#    'links': [{'length': '16378917',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-07.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Mon, 25 Sep 2017 23:00:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=25, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=268, tm_isdst=0),
#    'itunes_duration': '00:12:23',
#    'id': 'Origin of species 07',
#    'guidislink': False},
#   {'title': '06 - Машинное обучение',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '06 - Машинное обучение'},
#    'summary': 'Как машины учатся, и почему это не страшно',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Как машины учатся, и почему это не страшно'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'Как машины учатся, и почему это не страшно'}],
#    'links': [{'length': '18538618',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-06.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Tue, 29 Aug 2017 12:00:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2017, tm_mon=8, tm_mday=29, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=241, tm_isdst=0),
#    'itunes_duration': '00:15:47',
#    'id': 'Origin of species 06',
#    'guidislink': False},
#   {'title': '05 - Искусственный интеллект',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '05 - Искусственный интеллект'},
#    'summary': 'Сегодня очень бегло поговорили про искусственный интеллект, дальше будем разбирать его в деталях.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Сегодня очень бегло поговорили про искусственный интеллект, дальше будем разбирать его в деталях.'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'Сегодня очень бегло поговорили про искусственный интеллект, дальше будем разбирать его в деталях.'}],
#    'links': [{'length': '21717960',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-05.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Mon, 10 Jul 2017 12:00:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2017, tm_mon=7, tm_mday=10, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=191, tm_isdst=0),
#    'itunes_duration': '00:17:36',
#    'id': 'Origin of species 05',
#    'guidislink': False},
#   {'title': '04 - Слух людей и роботов',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '04 - Слух людей и роботов'},
#    'summary': 'Сегодня довольно гуманитарный выпуск - поговорим про слух человека и "слух" машин. \n        В выпуске я ссылаюсь на выпуск TED - вот на этот \n        https://www.ted.com/talks/michael_rubinstein_see_invisible_motion_hear_silent_sounds_cool_creepy_we_can_t_decide',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Сегодня довольно гуманитарный выпуск - поговорим про слух человека и "слух" машин. \n        В выпуске я ссылаюсь на выпуск TED - вот на этот \n        https://www.ted.com/talks/michael_rubinstein_see_invisible_motion_hear_silent_sounds_cool_creepy_we_can_t_decide'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'Сегодня довольно гуманитарный выпуск - поговорим про слух человека и "слух" машин. \n        В выпуске я ссылаюсь на выпуск TED - вот на этот \n        https://www.ted.com/talks/michael_rubinstein_see_invisible_motion_hear_silent_sounds_cool_creepy_we_can_t_decide'}],
#    'links': [{'length': '14525088',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-04.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Mon, 12 Jun 2017 12:00:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2017, tm_mon=6, tm_mday=12, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=163, tm_isdst=0),
#    'itunes_duration': '00:14:57',
#    'id': 'Origin of species 04',
#    'guidislink': False},
#   {'title': '03 - Зрение людей и роботов',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '03 - Зрение людей и роботов'},
#    'summary': 'Сегодня мы с железякой расскажем, почему зрение роботов позволит им выиграть в восстании машин.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Сегодня мы с железякой расскажем, почему зрение роботов позволит им выиграть в восстании машин.'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'Сегодня мы с железякой расскажем, почему зрение роботов позволит им выиграть в восстании машин.'}],
#    'links': [{'length': '13891138',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-03.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Sun, 4 Jun 2017 12:00:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2017, tm_mon=6, tm_mday=4, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=155, tm_isdst=0),
#    'itunes_duration': '00:13:37',
#    'id': 'Origin of species 03',
#    'guidislink': False},
#   {'title': '02 - Информация',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '02 - Информация'},
#    'summary': 'Сегодня мы коротко поговорим об информации - многие пользуются этим термином интуитивно, но в целом непонятно что это такое.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Сегодня мы коротко поговорим об информации - многие пользуются этим термином интуитивно, но в целом непонятно что это такое.'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'Сегодня мы коротко поговорим об информации - многие пользуются этим термином интуитивно, но в целом непонятно что это такое.'}],
#    'links': [{'length': '10689048',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-02.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Sun, 21 May 2017 12:00:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2017, tm_mon=5, tm_mday=21, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=141, tm_isdst=0),
#    'itunes_duration': '00:09:32',
#    'id': 'Origin of species 02',
#    'guidislink': False},
#   {'title': '01 - История языков программирования',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '01 - История языков программирования'},
#    'summary': 'Выпуск о том, как последние 60 с лишним лет развивались языки программирования.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Выпуск о том, как последние 60 с лишним лет развивались языки программирования.'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'Выпуск о том, как последние 60 с лишним лет развивались языки программирования.'}],
#    'links': [{'length': '27473625',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-01.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Mon, 01 May 2017 12:00:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2017, tm_mon=5, tm_mday=1, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=121, tm_isdst=0),
#    'itunes_duration': '00:22:01',
#    'id': 'Origin of species 01',
#    'guidislink': False},
#   {'title': '00 - История компьютеров',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': '00 - История компьютеров'},
#    'summary': 'Пилотный выпуск подкаста, в котором рассказывается о происхождении компьютеров, начиная с дикой древности.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Пилотный выпуск подкаста, в котором рассказывается о происхождении компьютеров, начиная с дикой древности.'},
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'http://sprotasov.ru/podcast/rss.xml',
#      'value': 'Пилотный выпуск подкаста, в котором рассказывается о происхождении компьютеров, начиная с дикой древности.'}],
#    'links': [{'length': '17526390',
#      'type': 'audio/mpeg',
#      'href': 'http://sprotasov.ru/podcast/origin-00.mp3',
#      'rel': 'enclosure'}],
#    'tags': [{'term': 'computer science', 'scheme': None, 'label': None}],
#    'published': 'Mon, 24 Apr 2017 12:00:00 +0300',
#    'published_parsed': time.struct_time(tm_year=2017, tm_mon=4, tm_mday=24, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=114, tm_isdst=0),
#    'itunes_duration': '00:13:37',
#    'id': 'Origin of species 00',
#    'guidislink': False}],
#  'feed': {'links': [{'href': 'http://sprotasov.ru/podcast/rss.xml',
#     'rel': 'self',
#     'type': 'application/rss+xml'},
#    {'rel': 'alternate', 'type': 'text/html', 'href': 'http://sprotasov.ru/'}],
#   'title': 'Происхождение видов',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://sprotasov.ru/podcast/rss.xml',
#    'value': 'Происхождение видов'},
#   'subtitle': 'Подкаст о том, как и зачем люди создают компьютеры, программы и искусственный интеллект.',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://sprotasov.ru/podcast/rss.xml',
#    'value': 'Подкаст о том, как и зачем люди создают компьютеры, программы и искусственный интеллект.'},
#   'summary': 'Подкаст о том, как и зачем люди создают компьютеры, программы и искусственный интеллект.',
#   'summary_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://sprotasov.ru/podcast/rss.xml',
#    'value': 'Подкаст о том, как и зачем люди создают компьютеры, программы и искусственный интеллект.'},
#   'tags': [{'term': 'компьютеры',
#     'scheme': 'http://www.itunes.com/',
#     'label': None},
#    {'term': 'программирование',
#     'scheme': 'http://www.itunes.com/',
#     'label': None},
#    {'term': 'искусственный интеллект',
#     'scheme': 'http://www.itunes.com/',
#     'label': None},
#    {'term': 'компьютерные науки',
#     'scheme': 'http://www.itunes.com/',
#     'label': None},
#    {'term': 'IT', 'scheme': 'http://www.itunes.com/', 'label': None},
#    {'term': 'Technology', 'scheme': 'http://www.itunes.com/', 'label': None}],
#   'authors': [{'name': 'Станислав Протасов',
#     'email': 'stanislav.i.protasov@ya.ru'}],
#   'author': 'Станислав Протасов',
#   'author_detail': {'name': 'Станислав Протасов',
#    'email': 'stanislav.i.protasov@ya.ru'},
#   'image': {'href': 'http://sprotasov.ru/podcast/cover.jpg',
#    'title': 'Происхождение видов',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Происхождение видов'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://sprotasov.ru/'}],
#    'link': 'http://sprotasov.ru/',
#    'subtitle': 'Происхождение видов',
#    'subtitle_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://sprotasov.ru/podcast/rss.xml',
#     'value': 'Происхождение видов'}},
#   'publisher_detail': {'name': 'Станислав Протасов',
#    'email': 'stanislav.i.protasov@ya.ru'},
#   'itunes_explicit': None,
#   'link': 'http://sprotasov.ru/',
#   'language': 'ru',
#   'rights': 'Станислав Протасов, 2017',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://sprotasov.ru/podcast/rss.xml',
#    'value': 'Станислав Протасов, 2017'},
#   'updated': 'Wed, 13 Sep 2017 12:00:10 +0300',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=9, tm_mday=13, tm_hour=9, tm_min=0, tm_sec=10, tm_wday=2, tm_yday=256, tm_isdst=0),
#   'published': 'Mon, 24 Apr 2017 12:00:00 +0300',
#   'published_parsed': time.struct_time(tm_year=2017, tm_mon=4, tm_mday=24, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=114, tm_isdst=0)},
#  'headers': {'x-powered-by': 'Express',
#   'accept-ranges': 'bytes',
#   'cache-control': 'public, max-age=0',
#   'last-modified': 'Mon, 14 Nov 2022 18:27:29 GMT',
#   'etag': 'W/"573c-18477657668"',
#   'content-type': 'text/xml; charset=UTF-8',
#   'content-length': '22332',
#   'date': 'Wed, 25 Jan 2023 10:56:09 GMT',
#   'connection': 'close'},
#  'etag': 'W/"573c-18477657668"',
#  'updated': 'Mon, 14 Nov 2022 18:27:29 GMT',
#  'updated_parsed': time.struct_time(tm_year=2022, tm_mon=11, tm_mday=14, tm_hour=18, tm_min=27, tm_sec=29, tm_wday=0, tm_yday=318, tm_isdst=0),
#  'href': 'http://sprotasov.ru/podcast/rss.xml',
#  'status': 200,
#  'encoding': 'UTF-8',
#  'version': 'rss20',
#  'namespaces': {'': 'http://www.w3.org/2005/Atom',
#   'content': 'http://purl.org/rss/1.0/modules/content/',
#   'itunes': 'http://www.itunes.com/dtds/podcast-1.0.dtd'}}

# %% [markdown]
# # 3. [EXTRA TASK] Solving simple information retrieval task
#
# According to the name, `information retrieval` is the discipline, which helps retrieves information (from unstructured sources). Thus, we will retrieve some information from [this news article](https://www.bbc.com/news/world-us-canada-59944889). Your task is to write a code, which will answer the question: **How many people die every day in the US waiting for a transplant?** Write flexible enough code. Test yourself by changing the link to [this one](https://www.americantransplantfoundation.org/about-transplant/facts-and-myths/).

# %%
import re

def find_answer(doc, question):
    pattern = r"\d+(?:,\d{3})*(?:\.\d+)?"
    keywords = ['people', 'die', 'every day', 'US', 'waiting', 'transplant']
    sentences = doc.stripped_strings

    for sentence in sentences:
        if all(keyword.lower() in sentence.lower() for keyword in keywords):
            numbers = re.findall(pattern, sentence)
            if numbers:
                return int(numbers[0].replace(',', ''))
    return None

# First URL
result = requests.get(url).text
doc = BeautifulSoup(result, "html.parser")
answer = find_answer(doc, question)
print(f"Answer from URL: {answer}")

# %%
def function(x, soup):
    if x in soup.text:#.strip():
        print(x)
        print("here")
    else:
        print("not here")

function("every day", doc)
# Out:
# every day
# here
